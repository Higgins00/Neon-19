# %%
import sympy as sym

L, d, n, b, ti, ti1 = sym.symbols('l D N B ti ti1', real = True)
sym.init_printing(use_unicode=True)

expression = (sym.log((d*n*sym.exp(-L*ti1)+b*d+1)/(d*n*sym.exp(-L*ti)+b*d+1)) + b*d*L*(ti-ti1))/(d*L*(b*d+1))

# %%
sym.diff(expression,L)
# Out:
#                  ⎛       ⎛           -l⋅ti₁    ⎞  -l⋅ti              -l⋅ti₁
#                  ⎜D⋅N⋅ti⋅⎝B⋅D + D⋅N⋅ℯ       + 1⎠⋅ℯ          D⋅N⋅ti₁⋅ℯ
#                  ⎜───────────────────────────────────── - ────────────────────
#                  ⎜                             2                     -l⋅ti
#                  ⎜       ⎛           -l⋅ti    ⎞           B⋅D + D⋅N⋅ℯ      + 1
#                  ⎝       ⎝B⋅D + D⋅N⋅ℯ      + 1⎠
# B⋅D⋅(ti - ti₁) + ─────────────────────────────────────────────────────────────
#                                                             -l⋅ti₁
#                                                  B⋅D + D⋅N⋅ℯ       + 1
# ──────────────────────────────────────────────────────────────────────────────
#                                             D⋅l⋅(B⋅D + 1)
#
#
# ⎞
# ⎟ ⎛           -l⋅ti    ⎞
# ⎟⋅⎝B⋅D + D⋅N⋅ℯ      + 1⎠
# ⎟
# ⎟                                                ⎛           -l⋅ti₁    ⎞
# ⎠                                                ⎜B⋅D + D⋅N⋅ℯ       + 1⎟
# ────────────────────────   B⋅D⋅l⋅(ti - ti₁) + log⎜─────────────────────⎟
#                                                  ⎜            -l⋅ti    ⎟
#                                                  ⎝ B⋅D + D⋅N⋅ℯ      + 1⎠
# ──────────────────────── - ─────────────────────────────────────────────
#                                               2
#                                            D⋅l ⋅(B⋅D + 1)

# %%
(𝐵𝐷(𝑡𝑖−𝑡𝑖1)+((𝐷*𝑁*𝑡𝑖*(𝐵*𝐷+𝐷*𝑁np.exp(−𝑙*𝑡𝑖1)+1)*np.exp(−𝑙*𝑡𝑖)/((𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1)**2) − (𝐷*𝑁*𝑡𝑖1*np.exp(−𝑙*𝑡𝑖1))/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1))*(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1))/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖1)+1))/(𝐷*𝑙*(𝐵*𝐷+1))  −  𝐵𝐷𝑙(𝑡𝑖−𝑡𝑖1)+log(𝐵𝐷+𝐷𝑁𝑒−𝑙𝑡𝑖1+1𝐵𝐷+𝐷𝑁𝑒−𝑙𝑡𝑖+1)𝐷𝑙2(𝐵𝐷+1)

# %%
sym.diff(expression,d)
# Out:
#                                                                        ⎛⎛
#                                                                        ⎜⎝-B -
#                                                                        ⎜──────
#                                                                        ⎜
#     ⎛                      ⎛           -l⋅ti₁    ⎞⎞                    ⎜
#     ⎜                      ⎜B⋅D + D⋅N⋅ℯ       + 1⎟⎟                    ⎝
#   B⋅⎜B⋅D⋅l⋅(ti - ti₁) + log⎜─────────────────────⎟⎟   B⋅l⋅(ti - ti₁) + ───────
#     ⎜                      ⎜            -l⋅ti    ⎟⎟
#     ⎝                      ⎝ B⋅D + D⋅N⋅ℯ      + 1⎠⎠
# - ───────────────────────────────────────────────── + ────────────────────────
#                                  2
#                     D⋅l⋅(B⋅D + 1)
#
#    -l⋅ti⎞ ⎛           -l⋅ti₁    ⎞             -l⋅ti₁    ⎞
# N⋅ℯ     ⎠⋅⎝B⋅D + D⋅N⋅ℯ       + 1⎠      B + N⋅ℯ          ⎟ ⎛           -l⋅ti
# ───────────────────────────────── + ────────────────────⎟⋅⎝B⋅D + D⋅N⋅ℯ      +
#                         2                      -l⋅ti    ⎟
#   ⎛           -l⋅ti    ⎞            B⋅D + D⋅N⋅ℯ      + 1⎟
#   ⎝B⋅D + D⋅N⋅ℯ      + 1⎠                                ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                      -l⋅ti₁
#                           B⋅D + D⋅N⋅ℯ       + 1
# ──────────────────────────────────────────────────────────────────────────────
#                      D⋅l⋅(B⋅D + 1)
#
#
#
#  ⎞
# 1⎠
#
#                            ⎛           -l⋅ti₁    ⎞
#                            ⎜B⋅D + D⋅N⋅ℯ       + 1⎟
# ──   B⋅D⋅l⋅(ti - ti₁) + log⎜─────────────────────⎟
#                            ⎜            -l⋅ti    ⎟
#                            ⎝ B⋅D + D⋅N⋅ℯ      + 1⎠
# ── - ─────────────────────────────────────────────
#                       2
#                      D ⋅l⋅(B⋅D + 1)

# %%
−(𝐵*(𝐵*𝐷*𝑙*(𝑡𝑖−𝑡𝑖1)+np.log((𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖1)+1)/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1))))/(𝐷*𝑙*(𝐵*𝐷+1)**2)  +  (𝐵*𝑙*(𝑡𝑖−𝑡𝑖1)+((((−𝐵−𝑁*np.exp(−𝑙𝑡𝑖))*(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖1)+1))/((𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙𝑡𝑖)+1)**2))+(𝐵+𝑁*np.exp(−𝑙*𝑡𝑖1))/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1))*(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1)/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖1)+1))/(𝐷*𝑙*(𝐵*𝐷+1))  −  (𝐵*𝐷*𝑙*(𝑡𝑖−𝑡𝑖1)+np.log((𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖1)+1)/(𝐵*𝐷+𝐷*𝑁*np.exp(−𝑙*𝑡𝑖)+1)))/((𝐷**2)*𝑙*(𝐵*𝐷+1))

# %%
sym.diff(expression,n)
# Out:
# ⎛        -l⋅ti₁           ⎛           -l⋅ti₁    ⎞  -l⋅ti⎞
# ⎜     D⋅ℯ               D⋅⎝B⋅D + D⋅N⋅ℯ       + 1⎠⋅ℯ     ⎟ ⎛           -l⋅ti
# ⎜──────────────────── - ────────────────────────────────⎟⋅⎝B⋅D + D⋅N⋅ℯ      +
# ⎜           -l⋅ti                                 2     ⎟
# ⎜B⋅D + D⋅N⋅ℯ      + 1       ⎛           -l⋅ti    ⎞      ⎟
# ⎝                           ⎝B⋅D + D⋅N⋅ℯ      + 1⎠      ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                    ⎛           -l⋅ti₁    ⎞
#                      D⋅l⋅(B⋅D + 1)⋅⎝B⋅D + D⋅N⋅ℯ       + 1⎠
#
#
#  ⎞
# 1⎠
#
#
#
# ──

# %%
(((𝐷*np.exp(−l*𝑡𝑖1)/(𝐵*𝐷+𝐷*𝑁*np.exp(−l*𝑡𝑖)+1) − (𝐷*(𝐵*𝐷+𝐷*𝑁*np.exp(−l*𝑡𝑖1)+1)*np.exp(−l*𝑡𝑖))/(𝐵*𝐷+𝐷*𝑁*np.exp(−l*𝑡𝑖)+1)**2)*(𝐵*𝐷+𝐷*𝑁*np.exp(−l*𝑡𝑖)+1))/(𝐷*l*(𝐵*𝐷+1)*(𝐵*𝐷+𝐷*𝑁*np.exp(−l*𝑡𝑖1)+1)))

# %%
sym.diff(expression,b)
# Out:
#                                                                    ⎛
#                                                                    ⎜         D
#                                                                    ⎜──────────
#                                                                    ⎜
#                         ⎛           -l⋅ti₁    ⎞                    ⎜B⋅D + D⋅N⋅
#                         ⎜B⋅D + D⋅N⋅ℯ       + 1⎟                    ⎝
#   B⋅D⋅l⋅(ti - ti₁) + log⎜─────────────────────⎟   D⋅l⋅(ti - ti₁) + ───────────
#                         ⎜            -l⋅ti    ⎟
#                         ⎝ B⋅D + D⋅N⋅ℯ      + 1⎠
# - ───────────────────────────────────────────── + ────────────────────────────
#                               2
#                    l⋅(B⋅D + 1)
#
#                ⎛           -l⋅ti₁    ⎞⎞
#              D⋅⎝B⋅D + D⋅N⋅ℯ       + 1⎠⎟ ⎛           -l⋅ti    ⎞
# ────────── - ─────────────────────────⎟⋅⎝B⋅D + D⋅N⋅ℯ      + 1⎠
#  -l⋅ti                              2 ⎟
# ℯ      + 1    ⎛           -l⋅ti    ⎞  ⎟
#               ⎝B⋅D + D⋅N⋅ℯ      + 1⎠  ⎠
# ──────────────────────────────────────────────────────────────
#                           -l⋅ti₁
#                B⋅D + D⋅N⋅ℯ       + 1
# ──────────────────────────────────────────────────────────────
#           D⋅l⋅(B⋅D + 1)

# %%
n, t, f = sym.symbols('n t f', real = True)
g = sym.Function('g')

ex = (1/2)*(((sym.Sum((g(t)*sym.cos(2*sym.pi*f*(t -((1/(4*sym.pi*f))*sym.atan(sym.Sum(sym.sin(4*sym.pi*f*t),(t,0,T))/sym.Sum(sym.cos(4*sym.pi*f*t),(t,0,T))))))),(t,0,T))**2)/sym.Sum(((sym.cos(2*sym.pi*f*(t -((1/(4*sym.pi*f))*sym.atan(sym.Sum(sym.sin(4*sym.pi*f*t),(t,0,T))/sym.Sum(sym.cos(4*sym.pi*f*t),(t,0,T)))))))**2),(t,0,T))) + ((sym.Sum((g(t)*sym.sin(2*sym.pi*f*(t -((1/(4*sym.pi*f))*sym.atan(sym.Sum(sym.sin(4*sym.pi*f*t),(t,0,T))/sym.Sum(sym.cos(4*sym.pi*f*t),(t,0,T))))))),(t,0,T))**2)/sym.Sum(((sym.sin(2*sym.pi*f*(t -((1/(4*sym.pi*f))*sym.atan(sym.Sum(sym.sin(4*sym.pi*f*t),(t,0,T))/sym.Sum(sym.cos(4*sym.pi*f*t),(t,0,T)))))))**2),(t,0,T))))

# %%
ex
# Out:
#                                                                  2
#     ⎛     T                                                     ⎞        ⎛
#     ⎜____________                                               ⎟        ⎜____
#     ⎜╲                                                          ⎟        ⎜╲
#     ⎜ ╲                   ⎛      ⎛        ⎛  T               ⎞⎞⎞⎟        ⎜ ╲
#     ⎜  ╲                  ⎜      ⎜        ⎜ ___              ⎟⎟⎟⎟        ⎜  ╲
#     ⎜   ╲                 ⎜      ⎜        ⎜ ╲                ⎟⎟⎟⎟        ⎜   ╲
#     ⎜    ╲                ⎜      ⎜        ⎜  ╲   sin(4⋅π⋅f⋅t)⎟⎟⎟⎟        ⎜
#     ⎜     ╲               ⎜      ⎜        ⎜  ╱               ⎟⎟⎟⎟        ⎜
#     ⎜      ╲              ⎜      ⎜        ⎜ ╱                ⎟⎟⎟⎟        ⎜
#     ⎜       ╲             ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟⎟        ⎜
#     ⎜        ╲            ⎜      ⎜        ⎜t = 0             ⎟⎟⎟⎟        ⎜
#     ⎜         ╲           ⎜      ⎜    atan⎜──────────────────⎟⎟⎟⎟        ⎜
#     ⎜          ╲          ⎜      ⎜        ⎜  T               ⎟⎟⎟⎟        ⎜
# 0.5⋅⎜          ╱          ⎜      ⎜        ⎜ ___              ⎟⎟⎟⎟    0.5⋅⎜
#     ⎜         ╱           ⎜      ⎜        ⎜ ╲                ⎟⎟⎟⎟        ⎜
#     ⎜        ╱            ⎜      ⎜        ⎜  ╲   cos(4⋅π⋅f⋅t)⎟⎟⎟⎟        ⎜
#     ⎜       ╱             ⎜      ⎜        ⎜  ╱               ⎟⎟⎟⎟        ⎜
#     ⎜      ╱              ⎜      ⎜        ⎜ ╱                ⎟⎟⎟⎟        ⎜
#     ⎜     ╱               ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟⎟        ⎜
#     ⎜    ╱                ⎜      ⎜        ⎝t = 0             ⎠⎟⎟⎟        ⎜
#     ⎜   ╱         g(t)⋅sin⎜2⋅π⋅f⋅⎜t - ────────────────────────⎟⎟⎟        ⎜   ╱
#     ⎜  ╱                  ⎝      ⎝             4⋅π⋅f          ⎠⎠⎟        ⎜  ╱
#     ⎜ ╱                                                         ⎟        ⎜ ╱
#     ⎜╱                                                          ⎟        ⎜╱
#     ⎜‾‾‾‾‾‾‾‾‾‾‾‾                                               ⎟        ⎜‾‾‾‾
#     ⎝   t = 0                                                   ⎠        ⎝   t
# ────────────────────────────────────────────────────────────────── + ─────────
#           T
#      ____________                                                         ____
#      ╲                                                                    ╲
#       ╲               ⎛      ⎛        ⎛  T               ⎞⎞⎞               ╲
#        ╲              ⎜      ⎜        ⎜ ___              ⎟⎟⎟                ╲
#         ╲             ⎜      ⎜        ⎜ ╲                ⎟⎟⎟                 ╲
#          ╲            ⎜      ⎜        ⎜  ╲   sin(4⋅π⋅f⋅t)⎟⎟⎟
#           ╲           ⎜      ⎜        ⎜  ╱               ⎟⎟⎟
#            ╲          ⎜      ⎜        ⎜ ╱                ⎟⎟⎟
#             ╲         ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟
#              ╲        ⎜      ⎜        ⎜t = 0             ⎟⎟⎟
#               ╲       ⎜      ⎜    atan⎜──────────────────⎟⎟⎟
#                ╲      ⎜      ⎜        ⎜  T               ⎟⎟⎟
#                ╱      ⎜      ⎜        ⎜ ___              ⎟⎟⎟
#               ╱       ⎜      ⎜        ⎜ ╲                ⎟⎟⎟
#              ╱        ⎜      ⎜        ⎜  ╲   cos(4⋅π⋅f⋅t)⎟⎟⎟
#             ╱         ⎜      ⎜        ⎜  ╱               ⎟⎟⎟
#            ╱          ⎜      ⎜        ⎜ ╱                ⎟⎟⎟
#           ╱           ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟
#          ╱           2⎜      ⎜        ⎝t = 0             ⎠⎟⎟
#         ╱         sin ⎜2⋅π⋅f⋅⎜t - ────────────────────────⎟⎟                 ╱
#        ╱              ⎝      ⎝             4⋅π⋅f          ⎠⎠                ╱
#       ╱                                                                    ╱
#      ╱                                                                    ╱
#      ‾‾‾‾‾‾‾‾‾‾‾‾                                                         ‾‾‾‾
#         t = 0                                                                t
#
#                                                         2
#  T                                                     ⎞
# ________                                               ⎟
#                                                        ⎟
#                  ⎛      ⎛        ⎛  T               ⎞⎞⎞⎟
#                  ⎜      ⎜        ⎜ ___              ⎟⎟⎟⎟
#                  ⎜      ⎜        ⎜ ╲                ⎟⎟⎟⎟
# ╲                ⎜      ⎜        ⎜  ╲   sin(4⋅π⋅f⋅t)⎟⎟⎟⎟
#  ╲               ⎜      ⎜        ⎜  ╱               ⎟⎟⎟⎟
#   ╲              ⎜      ⎜        ⎜ ╱                ⎟⎟⎟⎟
#    ╲             ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟⎟
#     ╲            ⎜      ⎜        ⎜t = 0             ⎟⎟⎟⎟
#      ╲           ⎜      ⎜    atan⎜──────────────────⎟⎟⎟⎟
#       ╲          ⎜      ⎜        ⎜  T               ⎟⎟⎟⎟
#       ╱          ⎜      ⎜        ⎜ ___              ⎟⎟⎟⎟
#      ╱           ⎜      ⎜        ⎜ ╲                ⎟⎟⎟⎟
#     ╱            ⎜      ⎜        ⎜  ╲   cos(4⋅π⋅f⋅t)⎟⎟⎟⎟
#    ╱             ⎜      ⎜        ⎜  ╱               ⎟⎟⎟⎟
#   ╱              ⎜      ⎜        ⎜ ╱                ⎟⎟⎟⎟
#  ╱               ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟⎟
# ╱                ⎜      ⎜        ⎝t = 0             ⎠⎟⎟⎟
#          g(t)⋅cos⎜2⋅π⋅f⋅⎜t - ────────────────────────⎟⎟⎟
#                  ⎝      ⎝             4⋅π⋅f          ⎠⎠⎟
#                                                        ⎟
#                                                        ⎟
# ‾‾‾‾‾‾‾‾                                               ⎟
#  = 0                                                   ⎠
# ─────────────────────────────────────────────────────────
#  T
# ________
#
#              ⎛      ⎛        ⎛  T               ⎞⎞⎞
#              ⎜      ⎜        ⎜ ___              ⎟⎟⎟
#              ⎜      ⎜        ⎜ ╲                ⎟⎟⎟
# ╲            ⎜      ⎜        ⎜  ╲   sin(4⋅π⋅f⋅t)⎟⎟⎟
#  ╲           ⎜      ⎜        ⎜  ╱               ⎟⎟⎟
#   ╲          ⎜      ⎜        ⎜ ╱                ⎟⎟⎟
#    ╲         ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟
#     ╲        ⎜      ⎜        ⎜t = 0             ⎟⎟⎟
#      ╲       ⎜      ⎜    atan⎜──────────────────⎟⎟⎟
#       ╲      ⎜      ⎜        ⎜  T               ⎟⎟⎟
#       ╱      ⎜      ⎜        ⎜ ___              ⎟⎟⎟
#      ╱       ⎜      ⎜        ⎜ ╲                ⎟⎟⎟
#     ╱        ⎜      ⎜        ⎜  ╲   cos(4⋅π⋅f⋅t)⎟⎟⎟
#    ╱         ⎜      ⎜        ⎜  ╱               ⎟⎟⎟
#   ╱          ⎜      ⎜        ⎜ ╱                ⎟⎟⎟
#  ╱           ⎜      ⎜        ⎜ ‾‾‾              ⎟⎟⎟
# ╱           2⎜      ⎜        ⎝t = 0             ⎠⎟⎟
#          cos ⎜2⋅π⋅f⋅⎜t - ────────────────────────⎟⎟
#              ⎝      ⎝             4⋅π⋅f          ⎠⎠
#
#
# ‾‾‾‾‾‾‾‾
#  = 0

# %%
sym.integrate(ex,f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-74-3d18c9c25ac7> in <module>
# ----> 1 sym.integrate(ex,f)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in integrate(*args, **kwargs)
#    1463     if isinstance(integral, Integral):
#    1464         return integral.doit(deep=False, meijerg=meijerg, conds=conds,
# -> 1465                              risch=risch, manual=manual)
#    1466     else:
#    1467         return integral
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in doit(self, **hints)
#     536                 else:
#     537                     antideriv = self._eval_integral(
# --> 538                         function, xab[0], **eval_kwargs)
#     539                     if antideriv is None and meijerg is True:
#     540                         ret = try_meijerg(function, xab)
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\integrals.py in _eval_integral(self, f, x, meijerg, risch, manual, conds)
#    1012             if h is None and manual is not False:
#    1013                 try:
# -> 1014                     result = manualintegrate(g, x)
#    1015                     if result is not None and not isinstance(result, Integral):
#    1016                         if result.has(Integral) and not manual:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in manualintegrate(f, var)
#    1377     sympy.integrals.integrals.Integral
#    1378     """
# -> 1379     result = _manualintegrate(integral_steps(f, var))
#    1380     # If we got Piecewise with two parts, put generic first
#    1381     if isinstance(result, Piecewise) and len(result.args) == 2:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1121             null_safe(trig_substitution_rule)
#    1122         ),
# -> 1123         fallback_rule)(integral)
#    1124     del _integral_cache[cachekey]
#    1125     return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     244         alts = []
#     245         for rule in rules:
# --> 246             result = rule(integral)
#     247             if (result and not isinstance(result, DontKnowRule) and
#     248                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in conditioned_rl(expr)
#      31     def conditioned_rl(expr):
#      32         if cond(expr):
# ---> 33             return rule(expr)
#      34         else:
#      35             return      expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     208             rewritten = rewrite(*integral)
#     209             if rewritten != integrand:
# --> 210                 substep = integral_steps(rewritten, symbol)
#     211                 if not isinstance(substep, DontKnowRule) and substep:
#     212                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1121             null_safe(trig_substitution_rule)
#    1122         ),
# -> 1123         fallback_rule)(integral)
#    1124     del _integral_cache[cachekey]
#    1125     return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     244         alts = []
#     245         for rule in rules:
# --> 246             result = rule(integral)
#     247             if (result and not isinstance(result, DontKnowRule) and
#     248                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _rewriter(integral)
#     208             rewritten = rewrite(*integral)
#     209             if rewritten != integrand:
# --> 210                 substep = integral_steps(rewritten, symbol)
#     211                 if not isinstance(substep, DontKnowRule) and substep:
#     212                     return RewriteRule(
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1121             null_safe(trig_substitution_rule)
#    1122         ),
# -> 1123         fallback_rule)(integral)
#    1124     del _integral_cache[cachekey]
#    1125     return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      93     def switch_rl(expr):
#      94         rl = ruledict.get(key(expr), identity)
# ---> 95         return rl(expr)
#      96     return switch_rl
#      97
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in add_rule(integral)
#     383     integrand, symbol = integral
#     384     results = [integral_steps(g, symbol)
# --> 385               for g in integrand.as_ordered_terms()]
#     386     return None if None in results else AddRule(results, integrand, symbol)
#     387
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in <listcomp>(.0)
#     383     integrand, symbol = integral
#     384     results = [integral_steps(g, symbol)
# --> 385               for g in integrand.as_ordered_terms()]
#     386     return None if None in results else AddRule(results, integrand, symbol)
#     387
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1121             null_safe(trig_substitution_rule)
#    1122         ),
# -> 1123         fallback_rule)(integral)
#    1124     del _integral_cache[cachekey]
#    1125     return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in switch_rl(expr)
#      93     def switch_rl(expr):
#      94         rl = ruledict.get(key(expr), identity)
# ---> 95         return rl(expr)
#      96     return switch_rl
#      97
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in mul_rule(integral)
#     392     # Constant times function case
#     393     coeff, f = integrand.as_independent(symbol)
# --> 394     next_step = integral_steps(f, symbol)
#     395
#     396     if coeff != 1 and next_step is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in integral_steps(integrand, symbol, **options)
#    1121             null_safe(trig_substitution_rule)
#    1122         ),
# -> 1123         fallback_rule)(integral)
#    1124     del _integral_cache[cachekey]
#    1125     return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in do_one_rl(expr)
#      83     def do_one_rl(expr):
#      84         for rl in rules:
# ---> 85             result = rl(expr)
#      86             if result != expr:
#      87                 return result
#
# ~\Anaconda3\lib\site-packages\sympy\strategies\core.py in null_safe_rl(expr)
#      63     """ Return original expr if rule returns None """
#      64     def null_safe_rl(expr):
# ---> 65         result = rule(expr)
#      66         if result is None:
#      67             return expr
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in _alternatives(integral)
#     244         alts = []
#     245         for rule in rules:
# --> 246             result = rule(integral)
#     247             if (result and not isinstance(result, DontKnowRule) and
#     248                 result != integral and result not in alts):
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in substitution_rule(integral)
#     899
#     900     u_var = sympy.Dummy("u")
# --> 901     substitutions = find_substitutions(integrand, symbol, u_var)
#     902     if substitutions:
#     903         ways = []
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in find_substitutions(integrand, symbol, u_var)
#     190             continue
#     191         u_diff = manual_diff(u, symbol)
# --> 192         new_integrand = test_subterm(u, u_diff)
#     193         if new_integrand is not False:
#     194             constant, new_integrand = new_integrand
#
# ~\Anaconda3\lib\site-packages\sympy\integrals\manualintegrate.py in test_subterm(u, u_diff)
#     136             return False
#     137
# --> 138         substituted = substituted.subs(u, u_var).cancel()
#     139         if symbol not in substituted.free_symbols:
#     140             return substituted.as_independent(u_var, as_Add=False)
#
# ~\Anaconda3\lib\site-packages\sympy\core\expr.py in cancel(self, *gens, **args)
#    3243         """See the cancel function in sympy.polys"""
#    3244         from sympy.polys import cancel
# -> 3245         return cancel(self, *gens, **args)
#    3246
#    3247     def invert(self, g, *gens, **args):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in cancel(f, *gens, **args)
#    6623             return f.xreplace(dict(reps))
#    6624
# -> 6625     c, P, Q = F.cancel(G)
#    6626
#    6627     if not isinstance(f, (tuple, Tuple)):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polytools.py in cancel(f, g, include)
#    3691
#    3692         if hasattr(F, 'cancel'):
# -> 3693             result = F.cancel(G, include=include)
#    3694         else:  # pragma: no cover
#    3695             raise OperationNotSupported(f, 'cancel')
#
# ~\Anaconda3\lib\site-packages\sympy\polys\polyclasses.py in cancel(f, g, include)
#     696             F, G = dmp_cancel(F, G, lev, dom, include=True)
#     697         else:
# --> 698             cF, cG, F, G = dmp_cancel(F, G, lev, dom, include=False)
#     699
#     700         F, G = per(F), per(G)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_cancel(f, g, u, K, include)
#    1872         cp, cq = K.one, K.one
#    1873
# -> 1874     _, p, q = dmp_inner_gcd(f, g, u, K)
#    1875
#    1876     if K0 is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     956         if not df:
#     957             F = dmp_LC(f, K)
# --> 958             G = dmp_content(g, u, K)
#     959         else:
#     960             F = dmp_content(f, u, K)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_content(f, u, K)
#    1798
#    1799     for c in f[1:]:
# -> 1800         cont = dmp_gcd(cont, c, v, K)
#    1801
#    1802         if dmp_one_p(cont, v, K):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_gcd(f, g, u, K)
#    1630
#    1631     """
# -> 1632     return dmp_inner_gcd(f, g, u, K)[0]
#    1633
#    1634
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_inner_gcd(f, g, u, K)
#    1589
#    1590     J, (f, g) = dmp_multi_deflate((f, g), u, K)
# -> 1591     h, cff, cfg = _dmp_inner_gcd(f, g, u, K)
#    1592
#    1593     return (dmp_inflate(h, J, u, K),
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_inner_gcd(f, g, u, K)
#    1558         if K.is_ZZ and query('USE_HEU_GCD'):
#    1559             try:
# -> 1560                 return dmp_zz_heu_gcd(f, g, u, K)
#    1561             except HeuristicGCDFailed:
#    1562                 pass
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in dmp_zz_heu_gcd(f, g, u, K)
#    1316         return dup_zz_heu_gcd(f, g, K)
#    1317
# -> 1318     result = _dmp_rr_trivial_gcd(f, g, u, K)
#    1319
#    1320     if result is not None:
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_rr_trivial_gcd(f, g, u, K)
#     916         return dmp_one(u, K), f, g
#     917     elif query('USE_SIMPLIFY_GCD'):
# --> 918         return _dmp_simplify_gcd(f, g, u, K)
#     919     else:
#     920         return None
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in _dmp_simplify_gcd(f, g, u, K)
#     965
#     966     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
# --> 967     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     968
#     969     return [h], cff, cfg
#
# ~\Anaconda3\lib\site-packages\sympy\polys\euclidtools.py in <listcomp>(.0)
#     965
#     966     cff = [ dmp_quo(cf, h, v, K) for cf in f ]
# --> 967     cfg = [ dmp_quo(cg, h, v, K) for cg in g ]
#     968
#     969     return [h], cff, cfg
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_quo(f, g, u, K)
#    1666
#    1667     """
# -> 1668     return dmp_div(f, g, u, K)[0]
#    1669
#    1670
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_div(f, g, u, K)
#    1624         return dmp_ff_div(f, g, u, K)
#    1625     else:
# -> 1626         return dmp_rr_div(f, g, u, K)
#    1627
#    1628
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1390     while True:
#    1391         lc_r = dmp_LC(r, K)
# -> 1392         c, R = dmp_rr_div(lc_r, lc_g, v, K)
#    1393
#    1394         if not dmp_zero_p(R, v):
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_rr_div(f, g, u, K)
#    1399         q = dmp_add_term(q, c, j, u, K)
#    1400         h = dmp_mul_term(g, c, j, u, K)
# -> 1401         r = dmp_sub(r, h, u, K)
#    1402
#    1403         _dr, dr = dr, dmp_degree(r, u)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in <listcomp>(.0)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# ~\Anaconda3\lib\site-packages\sympy\polys\densearith.py in dmp_sub(f, g, u, K)
#     656
#     657     if df == dg:
# --> 658         return dmp_strip([ dmp_sub(a, b, v, K) for a, b in zip(f, g) ], u)
#     659     else:
#     660         k = abs(df - dg)
#
# KeyboardInterrupt:
